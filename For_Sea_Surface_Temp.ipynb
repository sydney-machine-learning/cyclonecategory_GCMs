# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import xarray as xr
from datetime import datetime,timedelta
from matplotlib import pyplot as plt
from netCDF4 import Dataset

# %%
ds=Dataset(r'C:\Users\CHAITANYA AGRAWAL\OneDrive - IIT Delhi\Desktop\UNSW\SP_SST.nc')
url="https://raw.githubusercontent.com/sydney-machine-learning/cyclonedatasets/main/SouthIndian-SouthPacific-Ocean/South_pacific_hurricane.csv"
df = pd.read_csv(url, sep=',',error_bad_lines=False)
# Out:
# C:\Users\CHAITANYA AGRAWAL\AppData\Local\Temp\ipykernel_2332\2504426050.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(url, sep=',',error_bad_lines=False)

# %%
time=ds.variables['time'][:]
lat=ds.variables['latitude'][:]
lon=ds.variables['longitude'][:]
sst=ds.variables['sst']
ds['time']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int32 time(time)
#     units: hours since 1900-01-01 00:00:00.0
#     long_name: time
#     calendar: gregorian
# unlimited dimensions:
# current shape = (2040,)
# filling on, default _FillValue of -2147483647 used

# %%
df['Time']=pd.to_datetime(df['Time'],format='%Y%m%d%H')

# %%
intial=1900010100
initial_date=pd.to_datetime(intial,format='%Y%m%d%H')
df["diff"]=df['Time']-initial_date

# %%
df
# Out:
#       Basin  No. of Cycl                Time     V5  V6    Lat     Lon  \
# 0        SP           14 1982-01-25 18:00:00   BEST   0   180S   1541E
# 1        SP           14 1982-01-26 00:00:00   BEST   0   191S   1548E
# 2        SP           14 1982-01-26 06:00:00   BEST   0   197S   1557E
# 3        SP           14 1982-01-26 12:00:00   BEST   0   199S   1567E
# 4        SP           14 1982-01-26 18:00:00   BEST   0   201S   1578E
# ...     ...          ...                 ...    ...  ..    ...     ...
# 12002    SP           27 2019-05-15 18:00:00   BEST   0   118S   1396E
# 12003    SP           27 2019-05-16 00:00:00   BEST   0   112S   1385E
# 12004    SP           27 2019-05-16 06:00:00   BEST   0   112S   1374E
# 12005    SP           27 2019-05-16 12:00:00   BEST   0   109S   1362E
# 12006    SP           27 2019-05-16 18:00:00   BEST   0   103S   1352E
#
#        Speed(knots)  lat_tenth  lon_tenth                diff
# 0                25       18.0      154.1 29974 days 18:00:00
# 1                25       19.1      154.8 29975 days 00:00:00
# 2                25       19.7      155.7 29975 days 06:00:00
# 3                30       19.9      156.7 29975 days 12:00:00
# 4                35       20.1      157.8 29975 days 18:00:00
# ...             ...        ...        ...                 ...
# 12002            25       11.8      139.6 43598 days 18:00:00
# 12003            25       11.2      138.5 43599 days 00:00:00
# 12004            20       11.2      137.4 43599 days 06:00:00
# 12005            20       10.9      136.2 43599 days 12:00:00
# 12006            25       10.3      135.2 43599 days 18:00:00
#
# [12007 rows x 11 columns]

# %%
df['total']=(df['diff'][0]/timedelta(seconds=1))/3600
df['sst']=""

# %%
sst=ds.variables['sst'][:]

# %%
sst
# Out:
# masked_array(
#   data=[[[[301.6700702526542, 301.7013648054404, 301.71379688805405,
],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]]]],
#   fill_value=-32767)

# %%
for index,row in df.iterrows():
    latitude=row['lat_tenth']
    longitude=row['lon_tenth']
    total=row['total']
    
    diff_lat=(lat-latitude)**2
    diff_lon=(lon-longitude)**2
    diff_time=(time-total)**2
    
    
    min_lat=diff_lat.argmin()
    min_lon= diff_lon.argmin()
    min_time=diff_time.argmin()
    
    
    df.loc[index,'sst']=sst[min_time,0,min_lat,min_lon]

# %%
df
# Out:
#       Basin  No. of Cycl                Time     V5  V6    Lat     Lon  \
# 0        SP           14 1982-01-25 18:00:00   BEST   0   180S   1541E
# 1        SP           14 1982-01-26 00:00:00   BEST   0   191S   1548E
# 2        SP           14 1982-01-26 06:00:00   BEST   0   197S   1557E
# 3        SP           14 1982-01-26 12:00:00   BEST   0   199S   1567E
# 4        SP           14 1982-01-26 18:00:00   BEST   0   201S   1578E
# ...     ...          ...                 ...    ...  ..    ...     ...
# 12002    SP           27 2019-05-15 18:00:00   BEST   0   118S   1396E
# 12003    SP           27 2019-05-16 00:00:00   BEST   0   112S   1385E
# 12004    SP           27 2019-05-16 06:00:00   BEST   0   112S   1374E
# 12005    SP           27 2019-05-16 12:00:00   BEST   0   109S   1362E
# 12006    SP           27 2019-05-16 18:00:00   BEST   0   103S   1352E
#
#        Speed(knots)  lat_tenth  lon_tenth                diff     total  \
# 0                25       18.0      154.1 29974 days 18:00:00  719394.0
# 1                25       19.1      154.8 29975 days 00:00:00  719394.0
# 2                25       19.7      155.7 29975 days 06:00:00  719394.0
# 3                30       19.9      156.7 29975 days 12:00:00  719394.0
# 4                35       20.1      157.8 29975 days 18:00:00  719394.0
# ...             ...        ...        ...                 ...       ...
# 12002            25       11.8      139.6 43598 days 18:00:00  719394.0
# 12003            25       11.2      138.5 43599 days 00:00:00  719394.0
# 12004            20       11.2      137.4 43599 days 06:00:00  719394.0
# 12005            20       10.9      136.2 43599 days 12:00:00  719394.0
# 12006            25       10.3      135.2 43599 days 18:00:00  719394.0
#
#               sst
# 0      302.806534
# 1      302.752948
# 2      302.992158
# 3      302.756806
# 4      302.882841
# ...           ...
# 12002  302.444289
# 12003  302.061467
# 12004  302.315252
# 12005  302.124913
# 12006  302.127056
#
# [12007 rows x 13 columns]

# %%
time[0]
# Out:
# 692496

# %%
lat[0]
# Out:
# 0.0

# %%
lon[0]
df
# Out:
#       Basin  No. of Cycl                Time     V5  V6    Lat     Lon  \
# 0        SP           14 1982-01-25 18:00:00   BEST   0   180S   1541E
# 1        SP           14 1982-01-26 00:00:00   BEST   0   191S   1548E
# 2        SP           14 1982-01-26 06:00:00   BEST   0   197S   1557E
# 3        SP           14 1982-01-26 12:00:00   BEST   0   199S   1567E
# 4        SP           14 1982-01-26 18:00:00   BEST   0   201S   1578E
# ...     ...          ...                 ...    ...  ..    ...     ...
# 12002    SP           27 2019-05-15 18:00:00   BEST   0   118S   1396E
# 12003    SP           27 2019-05-16 00:00:00   BEST   0   112S   1385E
# 12004    SP           27 2019-05-16 06:00:00   BEST   0   112S   1374E
# 12005    SP           27 2019-05-16 12:00:00   BEST   0   109S   1362E
# 12006    SP           27 2019-05-16 18:00:00   BEST   0   103S   1352E
#
#        Speed(knots)  lat_tenth  lon_tenth                diff     total  \
# 0                25       18.0      154.1 29974 days 18:00:00  719394.0
# 1                25       19.1      154.8 29975 days 00:00:00  719394.0
# 2                25       19.7      155.7 29975 days 06:00:00  719394.0
# 3                30       19.9      156.7 29975 days 12:00:00  719394.0
# 4                35       20.1      157.8 29975 days 18:00:00  719394.0
# ...             ...        ...        ...                 ...       ...
# 12002            25       11.8      139.6 43598 days 18:00:00  719394.0
# 12003            25       11.2      138.5 43599 days 00:00:00  719394.0
# 12004            20       11.2      137.4 43599 days 06:00:00  719394.0
# 12005            20       10.9      136.2 43599 days 12:00:00  719394.0
# 12006            25       10.3      135.2 43599 days 18:00:00  719394.0
#
#               sst
# 0      302.806534
# 1      302.752948
# 2      302.992158
# 3      302.756806
# 4      302.882841
# ...           ...
# 12002  302.444289
# 12003  302.061467
# 12004  302.315252
# 12005  302.124913
# 12006  302.127056
#
# [12007 rows x 13 columns]

# %%
df
# Out:
#       Basin  No. of Cycl                Time     V5  V6    Lat     Lon  \
# 0        SP           14 1982-01-25 18:00:00   BEST   0   180S   1541E
# 1        SP           14 1982-01-26 00:00:00   BEST   0   191S   1548E
# 2        SP           14 1982-01-26 06:00:00   BEST   0   197S   1557E
# 3        SP           14 1982-01-26 12:00:00   BEST   0   199S   1567E
# 4        SP           14 1982-01-26 18:00:00   BEST   0   201S   1578E
# ...     ...          ...                 ...    ...  ..    ...     ...
# 12002    SP           27 2019-05-15 18:00:00   BEST   0   118S   1396E
# 12003    SP           27 2019-05-16 00:00:00   BEST   0   112S   1385E
# 12004    SP           27 2019-05-16 06:00:00   BEST   0   112S   1374E
# 12005    SP           27 2019-05-16 12:00:00   BEST   0   109S   1362E
# 12006    SP           27 2019-05-16 18:00:00   BEST   0   103S   1352E
#
#        Speed(knots)  lat_tenth  lon_tenth                diff     total  \
# 0                25       18.0      154.1 29974 days 18:00:00  719394.0
# 1                25       19.1      154.8 29975 days 00:00:00  719394.0
# 2                25       19.7      155.7 29975 days 06:00:00  719394.0
# 3                30       19.9      156.7 29975 days 12:00:00  719394.0
# 4                35       20.1      157.8 29975 days 18:00:00  719394.0
# ...             ...        ...        ...                 ...       ...
# 12002            25       11.8      139.6 43598 days 18:00:00  719394.0
# 12003            25       11.2      138.5 43599 days 00:00:00  719394.0
# 12004            20       11.2      137.4 43599 days 06:00:00  719394.0
# 12005            20       10.9      136.2 43599 days 12:00:00  719394.0
# 12006            25       10.3      135.2 43599 days 18:00:00  719394.0
#
#               sst
# 0      302.806534
# 1      302.752948
# 2      302.992158
# 3      302.756806
# 4      302.882841
# ...           ...
# 12002  302.444289
# 12003  302.061467
# 12004  302.315252
# 12005  302.124913
# 12006  302.127056
#
# [12007 rows x 13 columns]

# %%
df.to_csv("final.csv")
